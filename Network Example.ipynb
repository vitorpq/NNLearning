# %%
import network
import numpy as np

# %%
inputs = [(np.array([0, 0]), 0), (np.array([1, 0]), 0) , (np.array([0, 1]), 0), (np.array([1, 1]), 1)]

# %%
net = network.Network([2, 2, 1])
test_data = [np.array([0,1]),np.array([0,1]),np.array([0,1]),np.array([0,1])]

# %%
net.SGD(inputs, 1000, 1, 0.5, test_data)
# Out:
# Epoch 0: 0 / 4
# Epoch 1: 0 / 4
# Epoch 2: 0 / 4
# Epoch 3: 0 / 4
# Epoch 4: 0 / 4
# Epoch 5: 0 / 4
# Epoch 6: 0 / 4
# Epoch 7: 0 / 4
# Epoch 8: 0 / 4
# Epoch 9: 0 / 4
# Epoch 10: 0 / 4
# Epoch 11: 0 / 4
# Epoch 12: 0 / 4
# Epoch 13: 0 / 4
# Epoch 14: 0 / 4
# Epoch 15: 0 / 4
# Epoch 16: 0 / 4
# Epoch 17: 0 / 4
# Epoch 18: 0 / 4
# Epoch 19: 0 / 4
# Epoch 20: 0 / 4
# Epoch 21: 0 / 4
# Epoch 22: 0 / 4
# Epoch 23: 0 / 4
# Epoch 24: 0 / 4
# Epoch 25: 0 / 4
# Epoch 26: 0 / 4
# Epoch 27: 0 / 4
# Epoch 28: 0 / 4
# Epoch 29: 0 / 4
# Epoch 30: 0 / 4
# Epoch 31: 0 / 4
# Epoch 32: 0 / 4
# Epoch 33: 0 / 4
# Epoch 34: 0 / 4
# Epoch 35: 0 / 4
# Epoch 36: 0 / 4
# Epoch 37: 0 / 4
# Epoch 38: 0 / 4
# Epoch 39: 0 / 4
# Epoch 40: 0 / 4
# Epoch 41: 0 / 4
# Epoch 42: 0 / 4
# Epoch 43: 0 / 4
# Epoch 44: 0 / 4
# Epoch 45: 0 / 4
# Epoch 46: 0 / 4
# Epoch 47: 0 / 4
# Epoch 48: 0 / 4
# Epoch 49: 0 / 4
# Epoch 50: 0 / 4
# Epoch 51: 0 / 4
# Epoch 52: 0 / 4
# Epoch 53: 0 / 4
# Epoch 54: 0 / 4
# Epoch 55: 0 / 4
# ...

# %%
import mnist_loader

# %%
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()

# %%
import network
net = network.Network([784, 30, 10])

# %%
net.SGD(training_data, 30, 10, 3.0, test_data=test_data)
# Out:
# Epoch 0: 7949 / 10000
# Epoch 1: 9188 / 10000
# Epoch 2: 9243 / 10000
# Epoch 3: 9299 / 10000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-3c69aa07fa39> in <module>()
# ----> 1 net.SGD(training_data, 30, 10, 3.0, test_data=test_data)
#
# /home/vitor/Dropbox/Pos-Graduacao/Codigo/RNA/CancerMAT/network.py in SGD(self, training_data, epochs, mini_batch_size, eta, test_data)
#      60                 for k in xrange(0, n, mini_batch_size)]
#      61             for mini_batch in mini_batches:
# ---> 62                 self.update_mini_batch(mini_batch, eta)
#      63             if test_data:
#      64                 print "Epoch {0}: {1} / {2}".format(
#
# /home/vitor/Dropbox/Pos-Graduacao/Codigo/RNA/CancerMAT/network.py in update_mini_batch(self, mini_batch, eta)
#      75         nabla_w = [np.zeros(w.shape) for w in self.weights]
# ...
